# %%
import matplotlib.font_manager as fm
from pprint import pprint
import matplotlib.pyplot as plt

# %%
print(plt.rcParams['font.family']) # ['sans-serif']
print(plt.rcParams['font.size']) # 10.0
print(plt.rcParams['figure.figsize']) # [6.4, 4.8]
# Out:
# ['D2Coding', 'NanumGothic', 'NanumGothic']
# 10.0
# [6.4, 4.8]

# %%
import matplotlib.font_manager as fm
from pprint import pprint
sys_font = fm.findSystemFonts()
len(sys_font)
pprint(sys_font)
# Out:
# ['C:\\Windows\\Fonts\\JUICE___.TTF',
#  'C:\\Windows\\Fonts\\LBRITE.TTF',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\ANTQUAB.TTF',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\LBRITEI.TTF',
#  'C:\\Windows\\Fonts\\VINERITC.TTF',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\BOD_B.TTF',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\WINGDNG3.TTF',
#  'C:\\Windows\\Fonts\\CALIFI.TTF',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\BAUHS93.TTF',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\yumin.ttf',
# ...

# %%
d2coding = [f for f in sys_font if 'D2Coding' in f]
d2coding
# Out:
# ['C:\\Users\\hyenz\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc']

# %%
import matplotlib.font_manager as fm
path = r'C:\\Users\\hyenz\\AppData\\Local\\Microsoft\\Windows\\Fonts\\D2Coding-Ver1.3.2-20180524-all.ttc'
font_name = fm.FontProperties(fname=path, size=10).get_name()
plt.rcParams['font.family'] = 'D2Coding'
plt.rcParams['font.size'] = 10
plt.rcParams['figure.figsize'] = [6.4, 4.8]

# %%
print(plt.rcParams['font.family'])
print(plt.rcParams['font.size'])
print(plt.rcParams['figure.figsize'])
# Out:
# ['D2Coding']
# 10.0
# [6.4, 4.8]

# %% [markdown]
# # [출처](https://bizzengine.tistory.com/337)

# %%
import matplotlib.pyplot as plt
d2coding = [f for f in sys_font if 'D2Coding' in f]
d2coding
path = d2coding[0]
plt.rcParams['font.family'] = 'D2Coding'
plt.rcParams['font.size'] = 10
plt.rcParams['figure.figsize'] = [6.4, 4.8]

# %% [markdown]
# # [출처](https://012vision.tistory.com/entry/jupyter-%ED%95%9C%EA%B8%80-%ED%8F%B0%ED%8A%B8-%EC%98%81%EA%B5%AC-%EB%93%B1%EB%A1%9D)

# %%
import numpy as np
import matplotlib as mpl

print (mpl.matplotlib_fname())
# Out:
# c:\Users\hyenz\anaconda3\envs\ml\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline

# 사용자 운영체제 확인
import os
os.name

# 운영체제별 한글 폰트 설정
if os.name == 'posix': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif os.name == 'nt': # Windows 환경 폰트 설정
    plt.rc('font', family='D2Coding')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %%
# 파이썬 시각화 패키지 불러오기
import matplotlib.pyplot as plt
# %matplotlib inline

# 사용자 운영체제 확인
import platform
platform.system()

# 운영체제별 한글 폰트 설정
if platform.system() == 'Darwin': # Mac 환경 폰트 설정
    plt.rc('font', family='AppleGothic')
elif platform.system() == 'Windows': # Windows 환경 폰트 설정
    plt.rc('font', family='D2Coding')

plt.rc('axes', unicode_minus=False) # 마이너스 폰트 설정

# 글씨 선명하게 출력하는 설정
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## 테스트

# %%
import pandas as pd
d ={
    '가' : [1,2,3],
    '나' : [-4,5,6]
}
df = pd.DataFrame(d)
df.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='가,나'>

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

x = np.arange(-5, 5, 0.01)
y = np.sin(x)

plt.figure().add_subplot().set_title('한글/ -기호 테스트')
plt.plot(x, y)
