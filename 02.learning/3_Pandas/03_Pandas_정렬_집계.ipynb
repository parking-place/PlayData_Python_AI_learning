# %% [markdown]
# # 정렬
# ## index이름, column 이름을 기준으로 정렬
#
# - <b style='font-size:1.2em'>sort_index(axis, ascending=True)</b>
#     - axis
#         - index 이름 기준 정렬(행) : 'index' 또는 0 (기본값)
#         - column 이름 기준 정렬(열) : 'columns' 또는 1
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경

# %%
import pandas as pd
mdf = pd.read_csv(r'./data/movie.csv', index_col='movie_title')

# %%
# index명 기준으로 정렬렬
result = mdf.sort_index() # 오름차순 
result.head()
# Out:
#                             color        director_name
# movie_title
# #Horror                     Color         Tara Subkoff  \
# 10 Cloverfield Lane         Color     Dan Trachtenberg
# 10 Days in a Madhouse       Color        Timothy Hines
# 10 Things I Hate About You  Color           Gil Junger
# 10,000 B.C.                   NaN  Christopher Barnard
#
#                             num_critic_for_reviews  duration
# movie_title
# #Horror                                       35.0     101.0  \
# 10 Cloverfield Lane                          411.0     104.0
# 10 Days in a Madhouse                          1.0     111.0
# 10 Things I Hate About You                   133.0      97.0
# 10,000 B.C.                                    NaN      22.0
#
#                             director_facebook_likes  actor_3_facebook_likes
# movie_title
# #Horror                                        37.0                    56.0  \
# ...

# %%
result = mdf.sort_index(ascending=False) # 내림차순
result.head()
# Out:
#                          color     director_name  num_critic_for_reviews
# movie_title
# Æon Flux                 Color      Karyn Kusama                   178.0  \
# xXx: State of the Union  Color      Lee Tamahori                    77.0
# xXx                      Color         Rob Cohen                   191.0
# eXistenZ                 Color  David Cronenberg                   196.0
# [Rec] 2                  Color   Jaume Balagueró                   222.0
#
#                          duration  director_facebook_likes
# movie_title
# Æon Flux                     93.0                     45.0  \
# xXx: State of the Union     101.0                     93.0
# xXx                         132.0                    357.0
# eXistenZ                    115.0                      0.0
# [Rec] 2                      85.0                     57.0
#
#                          actor_3_facebook_likes    actor_2_name
# movie_title
# ...

# %%
result = mdf.sort_index(axis='columns') # columns 기준으로 정렬
result.head()
# Out:
#                                             actor_1_facebook_likes
# movie_title
# Avatar                                                      1000.0  \
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
#
#                                                actor_1_name
# movie_title
# Avatar                                          CCH Pounder  \
# Pirates of the Caribbean: At World's End        Johnny Depp
# Spectre                                     Christoph Waltz
# The Dark Knight Rises                             Tom Hardy
# Star Wars: Episode VII - The Force Awakens      Doug Walker
#
#                                             actor_2_facebook_likes
# movie_title
# Avatar                                                       936.0  \
# ...

# %%
# 부분일치로 슬라이싱 => 기본적으로는 안됨.
# index name이 정렬된 상태면 가능.
# mdf["A":"C"] -> 오류
mdf.sort_index()["A":"C"].head() # A~B까지 출력
# 소트시 loc을 사용하면 빠름.
# Out:
#                                        color         director_name
# movie_title
# A Beautiful Mind                       Color            Ron Howard  \
# A Beginner's Guide to Snuff            Color      Mitchell Altieri
# A Better Life                          Color           Chris Weitz
# A Bridge Too Far             Black and White  Richard Attenborough
# A Bug's Life                           Color         John Lasseter
#
#                              num_critic_for_reviews  duration
# movie_title
# A Beautiful Mind                              205.0     135.0  \
# A Beginner's Guide to Snuff                     NaN      87.0
# A Better Life                                  94.0      98.0
# A Bridge Too Far                               56.0     175.0
# A Bug's Life                                  117.0      95.0
#
#                              director_facebook_likes  actor_3_facebook_likes
# movie_title
# ...

# %% [markdown]
# ## 특정 컬럼(열)의 값을 기준으로 정렬
# - <b style='font-size:1.2em'>sort_values(by, ascending, inplace)</b>
#     - by
#         - **정렬 기준 컬럼이름**을 문자열로 지정
#         - 여러 컬럼에 대해 정렬할 경우 리스트에 담아 전달
#     - ascending
#         - 정렬방식
#         - True(기본): 오름차순, False: 내림차순
#         - 여러 컬럼에 대해 정렬할 경우 정렬방식도 리스트에 담아 전달
#     - inplace
#         - 원본에 적용 여부
#         - False(기본): 변경한 복사본 반환
#         - True : 원본을 변경
#     - 결측치는 방식과 상관없이 마지막에 나온다.

# %%
mdf.sort_values('duration').head() # duration 기준으로 오름차순 정렬
# Out:
#                                       color     director_name
# movie_title
# The Touch                             Color        Jane Clark  \
# Shaun the Sheep                       Color               NaN
# Robot Chicken                         Color               NaN
# Vessel                                Color       Clark Baker
# Wal-Mart: The High Cost of Low Price  Color  Robert Greenwald
#
#                                       num_critic_for_reviews  duration
# movie_title
# The Touch                                                NaN       7.0  \
# Shaun the Sheep                                         12.0       7.0
# Robot Chicken                                           38.0      11.0
# Vessel                                                   1.0      14.0
# Wal-Mart: The High Cost of Low Price                    56.0      20.0
#
#                                       director_facebook_likes
# movie_title
# ...

# %%
mdf.sort_values('duration', ascending=False).head() # duration 기준으로 내림차순 정렬
# Out:
#                           color        director_name  num_critic_for_reviews
# movie_title
# Trapped                   Color                  NaN                    16.0  \
# Carlos                    Color                  NaN                   108.0
# Blood In, Blood Out       Color      Taylor Hackford                    12.0
# Heaven's Gate             Color       Michael Cimino                   102.0
# The Legend of Suriyothai  Color  Chatrichalerm Yukol                    31.0
#
#                           duration  director_facebook_likes
# movie_title
# Trapped                      511.0                      NaN  \
# Carlos                       334.0                      NaN
# Blood In, Blood Out          330.0                    138.0
# Heaven's Gate                325.0                    517.0
# The Legend of Suriyothai     300.0                      6.0
#
#                           actor_3_facebook_likes              actor_2_name
# movie_title
# ...

# %%
mdf.sort_values(['duration', 'imdb_score'])[['duration', 'imdb_score']].head()
# duration 기준으로 오름차순 정렬 후, duration이 같은 경우 director_name 기준으로 오름차순 정렬
# Out:
#                                       duration  imdb_score
# movie_title
# The Touch                                  7.0         5.2
# Shaun the Sheep                            7.0         8.3
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8

# %%
mdf.sort_values(['duration', 'imdb_score'], ascending=[True, False])[['duration', 'imdb_score']].head()
# Out:
#                                       duration  imdb_score
# movie_title
# Shaun the Sheep                            7.0         8.3
# The Touch                                  7.0         5.2
# Robot Chicken                             11.0         7.8
# Vessel                                    14.0         6.2
# Wal-Mart: The High Cost of Low Price      20.0         6.8

# %%
mdf.query('duration >= 230').sort_values('duration').head() # duration이 0이 아닌 것만 출력
# Out:
#                                        color         director_name
# movie_title
# Dances with Wolves                     Color         Kevin Costner  \
# The Wolf of Wall Street                Color       Martin Scorsese
# Gandhi                       Black and White  Richard Attenborough
# Emma                                   Color                   NaN
# Once Upon a Time in America            Color          Sergio Leone
#
#                              num_critic_for_reviews  duration
# movie_title
# Dances with Wolves                             92.0     236.0  \
# The Wolf of Wall Street                       606.0     240.0
# Gandhi                                         95.0     240.0
# Emma                                           10.0     240.0
# Once Upon a Time in America                   111.0     251.0
#
#                              director_facebook_likes  actor_3_facebook_likes
# movie_title
# ...

# %%
result = mdf['director_name'].value_counts() # 각각의 갯수를 출력
result[result > 15] # 15개 이상인 것만 출력
result[result > 15].sort_index() # index 기준으로 정렬
result[result > 15].sort_index().plot(kind='bar') # index 기준으로 정렬 후, barh 그래프로 출력
# Out:
# <Axes: xlabel='director_name'>

# %% [markdown]
# # flights.csv (항공기 운항 기록 데이터)
# - MONTH : 비행 월
# - DAY : 비행 일
# - WEEKDAY : 비행 요일 - 1(월요일)~7(일요일)
# - AIRLINE : 항공사 코드
#      - UA:	United Air Lines Inc.
#      - AA:	American Airlines Inc.
#      - US:	US Airways Inc.
#      - F9:	Frontier Airlines Inc.
#      - B6:	JetBlue Airways
#      - OO:	Skywest Airlines Inc.
#      - AS:	Alaska Airlines Inc.
#      - NK:	Spirit Air Lines
#      - WN:	Southwest Airlines Co.
#      - DL:	Delta Air Lines Inc.
#      - EV:	Atlantic Southeast Airlines
#      - HA:	Hawaiian Airlines Inc.
#      - MQ:	American Eagle Airlines Inc.
#      - VX:	Virgin America
# - ORG_AIR : 출발공항
# - DEST_AIR : 도착공항
# - SCHED_DEP : 출발예정시각
# - DEP_DELAY : 출발지연시간(분)
# - AIR_TIME : 비행시간(분)
# - DIST : 비행거리(마일) -> 연속형(실수) -> 수치데이터
# - SCHED_ARR : 도착예정시각
# - ARR_DELAY : 도착지연시간(분)
# - DIVERTED : 회항여부(1: True, 0: False)
# - CANCELLED : 취소여부(1: True, 0: False)

# %%
import pandas as pd
flight = pd.read_csv(r'./data/flights.csv')
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58492 entries, 0 to 58491
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   MONTH      58492 non-null  int64
#  1   DAY        58492 non-null  int64
#  2   WEEKDAY    58492 non-null  int64
#  3   AIRLINE    58492 non-null  object
#  4   ORG_AIR    58492 non-null  object
#  5   DEST_AIR   58492 non-null  object
#  6   SCHED_DEP  58492 non-null  int64
#  7   DEP_DELAY  57659 non-null  float64
#  8   AIR_TIME   57474 non-null  float64
#  9   DIST       58492 non-null  int64
#  10  SCHED_ARR  58492 non-null  int64
#  11  ARR_DELAY  57474 non-null  float64
#  12  DIVERTED   58492 non-null  int64
#  13  CANCELLED  58492 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 6.2+ MB

# %%
flight.isnull().sum() # 각 컬럼별 null값의 갯수를 출력
# Out:
# MONTH           0
# DAY             0
# WEEKDAY         0
# AIRLINE         0
# ORG_AIR         0
# DEST_AIR        0
# SCHED_DEP       0
# DEP_DELAY     833
# AIR_TIME     1018
# DIST            0
# SCHED_ARR       0
# ARR_DELAY    1018
# DIVERTED        0
# CANCELLED       0
# dtype: int64

# %%
flight['AIRLINE'].value_counts(normalize=True) # 각 항공사별 갯수를 출력
# Out:
# AIRLINE
# DL    0.181238
# AA    0.152158
# WN    0.143917
# UA    0.133215
# OO    0.112631
# EV    0.100150
# MQ    0.059341
# US    0.027611
# NK    0.025918
# F9    0.022516
# VX    0.016977
# AS    0.013130
# B6    0.009283
# HA    0.001915
# Name: proportion, dtype: float64

# %%
flight['AIRLINE'].nunique() # 항공사 종류를 출력
# Out:
# 14

# %%
flight['WEEKDAY'].value_counts().sort_index() # 요일별 갯수를 출력
# Out:
# WEEKDAY
# 1    8720
# 2    8535
# 3    8706
# 4    8659
# 5    8453
# 6    7052
# 7    8367
# Name: count, dtype: int64

# %% [markdown]
# # 기술통계 메소드들을 이용한 데이터 집계
# ## 주요 기술통계 메소드
#
# |함수|설명|
# |-|-|
# |**sum()**|합계|
# |**mean()**|평균|
# |**median()**|중위수|
# |**mode()**|최빈값|
# |**quantile()**|분위수|
# |**std()**|표준편차|
# |**var()**|분산|
# |**count()**|결측치를 제외한 원소 개수|
# |**min()**|최소값|
# |**max()**|최대값|
# |**idxmax()**|최대값 index|
# |**idxmin()**|최소값 index|
# |**unique()**|고유값|
# |**nunique()**|고유값의 개수|
#
# <center><b style='font-size:1.2em'>cf) value_counts()는 Series에만 사용할 수 있다.</b></center>

# %% [markdown]
# - DataFrame에 위의 기술 통계 메소드들을 적용할 경우 **컬럼별로 계산한다.**
# - sum(), mode(), max(), min(), unique(), nunique(), count()는 **문자열에 적용가능하다.**
#     - idxmax(), idxmin() 는 문자열 컬럼에 사용할 수 없다. (문자열의 경우 넘파이의 argmax(), argmin() 함수를 사용한다.)

# %%
flight.mean(numeric_only=True) # 숫자형 컬럼의 평균값을 출력
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# AIR_TIME      115.928576
# DIST          872.900072
# SCHED_ARR    1549.399832
# ARR_DELAY       5.812315
# DIVERTED        0.002342
# CANCELLED       0.015062
# dtype: float64

# %%
flight['AIRLINE'].count() # 항공사 컬럼의 갯수를 출력
# Out:
# 58492

# %%
flight['AIRLINE'].max() # 항공사 컬럼의 최대값을 출력
# Out:
# 'WN'

# %%
import numpy as np
np.argmax(flight['AIRLINE']) # 항공사 컬럼의 최대값의 index를 출력
# Out:
# 0

# %% [markdown]
# - **공통 매개변수**
#     - skipna=True(기본값)
#         - 결측치(NA)를 포함해서 계산할지 여부 설정.
#         - True가 기본값으로 결측치(NA)를 제외하고 처리한다.
#         - 결측치 제외하지 않으려면 skipna=False로 설정하는데 결측치가 있으면 결과는 결측치가 된다.
#     - axis
#         - DataFrame에 적용할 때 계산방향을 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계

# %% [markdown]
# ## aggregate(func, axis=0, \*args, \*\*kwargs) 또는 agg(func, axis=0, \*args, \*\*kwargs)
# - DataFrame, Series의 메소드로 **집계결과를 다양한 형태로 묶어서 볼 때** 사용한다.
#     - **사용자 정의 집계메소드를 사용할 때도 편리하다.**
# - **매개변수**
#     - func
#         - 집계 함수 지정
#             - 함수명/함수리스트 (문자열)
#                 - 판다스 제공 집계메소드들은 문자열로, 사용자정의 집계함수는 함수 객체로 전달
#             - Dictionary : {'집계할컬럼' : 집계함수, ... }
#                 - 컬럼별로 다른 집계를 할 경우
#     - axis
#         - DataFrame에 적용할 때 0 방향으로 계산할 지 1 방향으로 계산할지 설정
#             - 0 또는 'index' (기본값): 컬럼 방향으로 집계
#             - 1 또는 'columns': 행 방향으로 집계
#     - \*args, \*\*kwargs
#         - 함수에 전달할 매개변수.
#         - 집계함수는 첫번째 매개변수로 Series를 받는다. 그 이외의 매개변수가 있는 경우.

# %%
flight.mean(numeric_only=True).head() # 숫자형 컬럼의 평균값을 barh 그래프로 출력
# Out:
# MONTH           6.220646
# DAY            15.702096
# WEEKDAY         3.926862
# SCHED_DEP    1387.984836
# DEP_DELAY      10.921192
# dtype: float64

# %%
flight['ARR_DELAY'].mean(), flight['ARR_DELAY'].max()
# Out:
# (5.812315133799631, 1185.0)

# %%
flight['ARR_DELAY'].aggregate(['mean', 'max']) # ARR_DELAY 컬럼의 평균값과 최대값을 출력
# Out:
# mean       5.812315
# max     1185.000000
# Name: ARR_DELAY, dtype: float64

# %%
flight['ARR_DELAY'].agg(['mean', 'max']) # ARR_DELAY 컬럼의 평균값과 최대값을 출력
# agg는 aggregate와 같은 기능을 함.
# Out:
# mean       5.812315
# max     1185.000000
# Name: ARR_DELAY, dtype: float64

# %%
flight['ARR_DELAY'].mean(skipna=False)
# Out:
# nan

# %%
flight['ARR_DELAY'].agg('mean', skipna=False) # skipna 값을 agg 함수의 인자로 전달
# Out:
# nan

# %%
flight['ARR_DELAY'].agg(['mean', 'max'], skipna=False)
# 공통 파라미터의 경우는 적용가능
# 공통죄지 않은 파라미터의 경우는 오류 발생
# Out:
# mean   NaN
# max    NaN
# Name: ARR_DELAY, dtype: float64

# %%
pd.__version__
# Out:
# '2.0.0'

# %%
# 컬럼별로 다른 집계
# 딕셔너리 형태로 칼럼명과 집계함수를 전달
# key: 컬럼명, value: 집계함수(들)
d = {
    'DEP_DELAY': 'sum',
    'ARR_DELAY': ['min', 'max']
}
flight.agg(d)
# Out:
#      DEP_DELAY  ARR_DELAY
# sum   629705.0        NaN
# min        NaN      -60.0
# max        NaN     1185.0

# %%
# DEP_DELAY, ARR_DELAY 의 평균, 표준편차를 조회
flight[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'])
# Out:
#       DEP_DELAY  ARR_DELAY
# mean  10.921192   5.812315
# std   36.146210  38.411948

# %%
# DEP_DELAY, ARR_DELAY 의 평균, 표준편차를 조회 -> 행별로 출력
# 50000개라 오래걸림
flight[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'], axis=1).head()
# Out:
#    mean        std
# 0  61.5   4.949747
# 1  -3.0  14.142136
# 2  35.5   0.707107
# 3   0.0   9.899495
# 4  43.5   6.363961

# %%
# 넘버릭 자료들의 집계
flight.select_dtypes(exclude='object').agg(['count', 'mean', 'std', 'min', 'max', 'median', 'skew'])
# Out:
#                MONTH           DAY       WEEKDAY     SCHED_DEP     DEP_DELAY
# count   58492.000000  58492.000000  58492.000000  58492.000000  57659.000000  \
# mean        6.220646     15.702096      3.926862   1387.984836     10.921192
# std         3.358484      8.760846      1.995777    482.810792     36.146210
# min         1.000000      1.000000      1.000000      5.000000    -24.000000
# max        12.000000     31.000000      7.000000   2359.000000   1194.000000
# median      6.000000     16.000000      4.000000   1353.000000     -1.000000
# skew        0.173245      0.008699      0.063433      0.012206      6.406516
#
#             AIR_TIME          DIST     SCHED_ARR     ARR_DELAY      DIVERTED
# count   57474.000000  58492.000000  58492.000000  57474.000000  58492.000000  \
# mean      115.928576    872.900072   1549.399832      5.812315      0.002342
# std        71.679591    624.996805    518.599952     38.411948      0.048340
# ...

# %% [markdown]
# # Groupby
# - 특정 열을 기준으로 같은 값을 가지는 행끼리 묶어서 group화 한다.
# - **~~ 별 집계를 할 때** 사용한다. (성별, 직급별, 등급별 ...)
#     - Group으로 묶을 기준 열은 범주형타입(category)을 사용한다.
# - **구문**
#     - `DF.groupby('그룹으로묶을기준컬럼')`
#         - DataFrameGroupby 객체를 반환한다.
#         - DataFrameGroupby 객체는 어떤 행끼리 묶여있는지 정보를 가진다. 이 객체의 집계함수를 사용하면 그룹별 집계를 할 수 있다.
#             - `DataFrameGroupby객체['집계할 컬럼'].집계함수()`
#         - groupby에 여러개의 컬럼을 기준으로 나눌 경우 리스트에 묶어서 전달한다.
#         - 집계할 컬럼이 여러개인 경우 리스트로 묶어준다.
#     - 집계함수
#         - 기술통계 함수들
#         - agg()/aggregate()
#             - 여러 다른 집계함수 호출시(여러 집계를 같이 볼경우)
#             - 사용자정의 집계함수 호출시
#             - 컬럼별로 다른 집계함수들을 호출할 경우

# %%
flight['AIRLINE'].unique() # 항공사 종류를 출력
# Out:
# array(['WN', 'UA', 'MQ', 'AA', 'F9', 'EV', 'OO', 'NK', 'US', 'AS', 'DL',
#        'VX', 'B6', 'HA'], dtype=object)

# %%
# groupby 메소드를 이용해서 항공사별로 그룹화
airlines = flight.groupby('AIRLINE')

# %%
airlines.groups # 그룹화된 데이터를 출력
# 딕셔너리 형태로 출력됨.
# Key: 그룹화된 데이터의 이름
# Value: 이름에 해당하는 데이터의 인덱스
# Out:
# {'AA': [3, 6, 8, 15, 26, 32, 33, 36, 37, 41, 46, 47, 48, 55, 62, 66, 73, 75, 76, 87, 89, 97, 98, 107, 120, 122, 128, 131, 133, 146, 160, 171, 174, 178, 179, 188, 200, 201, 206, 221, 267, 270, 279, 305, 309, 311, 321, 330, 332, 342, 343, 347, 348, 380, 381, 382, 390, 393, 398, 402, 404, 405, 419, 427, 430, 431, 441, 449, 451, 455, 457, 466, 476, 491, 493, 497, 509, 514, 521, 527, 528, 537, 550, 551, 556, 560, 568, 572, 587, 589, 592, 612, 613, 618, 624, 626, 628, 634, 640, 652, ...], 'AS': [38, 198, 241, 277, 397, 450, 453, 500, 518, 591, 718, 737, 741, 808, 820, 867, 872, 1005, 1106, 1146, 1292, 1437, 1530, 1559, 1609, 1636, 1747, 1786, 1810, 1826, 1892, 1921, 2010, 2151, 2269, 2446, 2526, 2576, 2586, 2941, 3112, 3125, 3171, 3176, 3413, 3483, 3494, 3596, 3678, 3734, 3891, 3910, 3937, 3989, 4099, 4128, 4326, 4397, 4432, 4587, 4743, 4799, 4841, 4850, 4912, 4987, 5099, 5154, 5176, 5254, 5261, 5297, 5356, 5372, 5496, 5667, 5685, 5688, 5877, 5976, 6016, 6079, 6122, 6245, 6255, 6393, 6529,
# ...

# %%
# 항공사별 각 컬럼들의 평균값
airlines.mean(numeric_only=True).head()
# Out:
#             MONTH        DAY   WEEKDAY    SCHED_DEP  DEP_DELAY    AIR_TIME
# AIRLINE
# AA       6.661461  15.570562  3.986966  1340.140449  11.274057  144.259404  \
# AS       6.197917  15.247396  3.941406  1418.269531   1.808594  147.845052
# B6       6.368324  15.788214  4.040516  1512.924494  14.287823  209.412963
# DL       6.277332  15.721158  3.913310  1426.563154   7.242450  115.334187
# EV       6.003926  15.866166  3.927450  1415.510413   9.092625   68.964016
#
#                 DIST    SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# AIRLINE
# AA       1114.347865  1546.960899   5.542661  0.002921   0.017303
# AS       1065.884115  1548.292969  -0.833333  0.000000   0.000000
# B6       1771.882136  1432.889503   8.692593  0.003683   0.001842
# DL        866.448448  1578.735402   0.339691  0.002264   0.003585
# EV        460.237453  1571.798054   7.034580  0.002561   0.024923

# %%
# 항공사별 도착 지연 시간의 평균값, iqr
flight.groupby('AIRLINE')['ARR_DELAY'].agg(['mean', iqr])
# Out:
#               mean    iqr
# AIRLINE
# AA        5.542661  23.00
# AS       -0.833333  18.00
# B6        8.692593  28.25
# DL        0.339691  18.00
# EV        7.034580  21.00
# F9       13.630651  27.00
# HA        4.972973  21.00
# MQ        6.860591  25.00
# NK       18.436070  34.00
# OO        7.593463  22.00
# UA        7.765755  25.00
# US        1.681105  19.00
# VX        5.348884  19.00
# WN        6.397353  23.00

# %%
# 항공사별 도착 지연 시간의 평균값, iqr
flight.groupby('AIRLINE')['ARR_DELAY'].mean()
# Out:
# AIRLINE
# AA     5.542661
# AS    -0.833333
# B6     8.692593
# DL     0.339691
# EV     7.034580
# F9    13.630651
# HA     4.972973
# MQ     6.860591
# NK    18.436070
# OO     7.593463
# UA     7.765755
# US     1.681105
# VX     5.348884
# WN     6.397353
# Name: ARR_DELAY, dtype: float64

# %%
# 항공사별 출발/도착 지연시간 평균, iqr
flight.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', iqr])
# Out:
#          DEP_DELAY         ARR_DELAY
#               mean    iqr       mean    iqr
# AIRLINE
# AA       11.274057  14.00   5.542661  23.00
# AS        1.808594   8.00  -0.833333  18.00
# B6       14.287823  20.75   8.692593  28.25
# DL        7.242450   8.00   0.339691  18.00
# EV        9.092625  12.00   7.034580  21.00
# F9       14.310398  20.00  13.630651  27.00
# HA        2.571429   6.25   4.972973  21.00
# MQ       11.094323  16.00   6.860591  25.00
# NK       19.514401  27.00  18.436070  34.00
# OO        9.662279  13.00   7.593463  22.00
# UA       16.210485  18.00   7.765755  25.00
# US        4.361355   7.00   1.681105  19.00
# VX        8.918946   9.00   5.348884  19.00
# WN       12.639366  18.00   6.397353  23.00

# %%
# 항공사별 출발/도착 지연시간 평균, 표준편차
flight.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'])
# Out:
#          DEP_DELAY             ARR_DELAY
#               mean        std       mean        std
# AIRLINE
# AA       11.274057  40.787806   5.542661  43.323160
# AS        1.808594  29.543702  -0.833333  31.168354
# B6       14.287823  36.863416   8.692593  40.221718
# DL        7.242450  29.759377   0.339691  32.299471
# EV        9.092625  34.582917   7.034580  36.682336
# F9       14.310398  51.773844  13.630651  53.030912
# HA        2.571429  33.880743   4.972973  37.528283
# MQ       11.094323  31.159293   6.860591  36.324657
# NK       19.514401  46.484632  18.436070  48.727259
# OO        9.662279  33.413767   7.593463  35.331344
# UA       16.210485  44.834336   7.765755  46.405935
# US        4.361355  24.550930   1.681105  27.030227
# VX        8.918946  31.782085   5.348884  33.747675
# WN       12.639366  30.506549   6.397353  32.610666

# %%
# 항공사별 출발/도착 지연시간 평균, 표준편차 -> DEP_DELAY mean을 기준으로 내림차순 정렬
flight.groupby('AIRLINE')[['DEP_DELAY', 'ARR_DELAY']]\
    .agg(['mean', 'std']).sort_values(('DEP_DELAY', 'mean'), ascending=False)
# Out:
#          DEP_DELAY             ARR_DELAY
#               mean        std       mean        std
# AIRLINE
# NK       19.514401  46.484632  18.436070  48.727259
# UA       16.210485  44.834336   7.765755  46.405935
# F9       14.310398  51.773844  13.630651  53.030912
# B6       14.287823  36.863416   8.692593  40.221718
# WN       12.639366  30.506549   6.397353  32.610666
# AA       11.274057  40.787806   5.542661  43.323160
# MQ       11.094323  31.159293   6.860591  36.324657
# OO        9.662279  33.413767   7.593463  35.331344
# EV        9.092625  34.582917   7.034580  36.682336
# VX        8.918946  31.782085   5.348884  33.747675
# DL        7.242450  29.759377   0.339691  32.299471
# US        4.361355  24.550930   1.681105  27.030227
# HA        2.571429  33.880743   4.972973  37.528283
# AS        1.808594  29.543702  -0.833333  31.168354

# %%
# 요일별 출발 지연시간, 도착 지연시간 평균, 표준편차
flight.groupby('WEEKDAY')[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'])
# Out:
#          DEP_DELAY            ARR_DELAY
#               mean        std      mean        std
# WEEKDAY
# 1        12.546447  39.024511  7.920024  41.554703
# 2        10.256383  35.838668  5.004644  37.720026
# 3        10.582201  36.491639  5.560541  38.637267
# 4        11.505021  34.914016  7.133966  37.574161
# 5        10.789574  35.115184  5.691994  37.613145
# 6         9.333669  36.504116  3.057856  38.219092
# 7        11.142371  34.900221  5.796170  37.135637

# %% [markdown]
# ##  복수열 기준 그룹핑
# - 두개 이상의 열을 그룹으로 묶을 수 있다.
# - groupby의 매개변수에 그룹으로 묶을 컬럼들의 이름을 리스트로 전달한다.

# %%
# 항공사, 요일별 출발,도착 지연시간 평균, 표준편차
flight.groupby(['AIRLINE', 'WEEKDAY'])[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'])
# Out:
#                  DEP_DELAY            ARR_DELAY
#                       mean        std      mean        std
# AIRLINE WEEKDAY
# AA      1        14.385610  45.964379  9.135772  49.116029
#         2         9.101890  40.515199  3.009053  42.545285
#         3         9.285498  34.104305  2.979561  36.733339
#         4        11.764840  36.189212  6.474771  38.883718
#         5        11.271132  42.909320  6.743017  45.702253
# ...                    ...        ...       ...        ...
# WN      3        11.463007  28.440273  5.370518  29.594558
#         4        13.893312  29.888741  8.524800  33.117446
#         5        13.102178  30.097906  6.722781  32.472688
#         6         9.925281  26.591351  2.449692  29.286778
#         7        12.619006  29.967762  6.398601  32.164606
#
# [98 rows x 4 columns]

# %%
# 항공사, 요일별 출발,도착 지연시간 평균, 표준편차를 DEP_DELAY mean을 기준으로 값이 10이상인 것만 출력
flight.groupby(['AIRLINE', 'WEEKDAY'])[['DEP_DELAY', 'ARR_DELAY']].agg(['mean', 'std'])
# Out:
#                  DEP_DELAY            ARR_DELAY
#                       mean        std      mean        std
# AIRLINE WEEKDAY
# AA      1        14.385610  45.964379  9.135772  49.116029
#         2         9.101890  40.515199  3.009053  42.545285
#         3         9.285498  34.104305  2.979561  36.733339
#         4        11.764840  36.189212  6.474771  38.883718
#         5        11.271132  42.909320  6.743017  45.702253
# ...                    ...        ...       ...        ...
# WN      3        11.463007  28.440273  5.370518  29.594558
#         4        13.893312  29.888741  8.524800  33.117446
#         5        13.102178  30.097906  6.722781  32.472688
#         6         9.925281  26.591351  2.449692  29.286778
#         7        12.619006  29.967762  6.398601  32.164606
#
# [98 rows x 4 columns]

# %%
result = flight.groupby(['AIRLINE', 'WEEKDAY'])['DEP_DELAY'].agg('mean')
# to_frame() : Series를 DataFrame으로 변환
result.to_frame()
# Out:
#                  DEP_DELAY
# AIRLINE WEEKDAY
# AA      1        14.385610
#         2         9.101890
#         3         9.285498
#         4        11.764840
#         5        11.271132
# ...                    ...
# WN      3        11.463007
#         4        13.893312
#         5        13.102178
#         6         9.925281
#         7        12.619006
#
# [98 rows x 1 columns]

# %%
# 출발공항, 도착공항별 출발 지연시간 평균
# ORG_AIR -> 출발공항, DEST_AIR -> 도착공항
result = flight.groupby(['ORG_AIR', 'DEST_AIR'])['DEP_DELAY'].mean()
result.to_frame()
# Out:
#                   DEP_DELAY
# ORG_AIR DEST_AIR
# ATL     ABE        9.612903
#         ABQ        7.062500
#         ABY       22.473684
#         ACY        7.166667
#         AEX       11.000000
# ...                     ...
# SFO     SNA        8.483051
#         STL       25.100000
#         SUN       17.700000
#         TUS       14.200000
#         XNA       -3.000000
#
# [1130 rows x 1 columns]

# %%
# 출발공항, 도착공항별 출발 지연시간의 최대값, 최소값, 최대값-최소값
def max_min_diff(x : pd.Series):
    max_v = x.max()
    min_v = x.min()
    return max_v - min_v

flight.groupby(['ORG_AIR', 'DEST_AIR'])['DEP_DELAY'].agg(['min', 'max', max_min_diff]).query('max_min_diff < 100')
# Out:
#                    min   max  max_min_diff
# ORG_AIR DEST_AIR
# ATL     ABQ       -3.0  78.0          81.0
#         ACY       -3.0  19.0          22.0
#         ALB       -8.0  87.0          95.0
#         ANC        5.0   6.0           1.0
#         ASE       57.0  57.0           0.0
# ...                ...   ...           ...
# SFO     RDU      -10.0  67.0          77.0
#         SBP      -13.0  75.0          88.0
#         SMX      -16.0  30.0          46.0
#         SUN       -8.0  66.0          74.0
#         XNA       -5.0  -1.0           4.0
#
# [439 rows x 3 columns]

# %% [markdown]
# ## Group 별 집계결과에서 특정 조건의 항목만 조회
# - Groupby 집계 후 boolean indexing 처리한다.

# %%
# 항공사별 취소건수
flight.groupby('AIRLINE')['CANCELLED'].sum()
# Out:
# AIRLINE
# AA    154
# AS      0
# B6      1
# DL     38
# EV    146
# F9     10
# HA      0
# MQ    152
# NK     25
# OO    142
# UA     93
# US     21
# VX      6
# WN     93
# Name: CANCELLED, dtype: int64

# %%
# 항공사별 취소건수가 100건 이상인 항공사만 조회
result = flight.groupby('AIRLINE')['CANCELLED'].sum()
result[result >= 100]
# Out:
# AIRLINE
# AA    154
# EV    146
# MQ    152
# OO    142
# Name: CANCELLED, dtype: int64

# %%
# 항공사별 취소건수가 100건 이상인 항공사만 조회
flight.groupby('AIRLINE')['CANCELLED'].sum().to_frame().query('CANCELLED > 100')
# Out:
#          CANCELLED
# AIRLINE
# AA             154
# EV             146
# MQ             152
# OO             142

# %% [markdown]
# # 사용자 정의 집계함수를 만들어 적용
#
# ## 사용자 정의 집계 함수 정의
# - Parameter(매개변수)
#     1. Series 또는 DataFrame을 받을 매개변수(필수)
#     2. 필요한 값을 받을 매개변수를 선언한다. (선택)

# %%
# 사용자 정의 집계 함수 -> agg 함수에서 사용하고 싶을때
### 첫번째 파라미터: 통계량을 구할 Series
### 
### 반환값: 계산된 통계량

# 최댓값과 최소값의 차이를 구하는 함수
def max_min_diff(x : pd.Series):
    max_v = x.max()
    min_v = x.min()
    return max_v - min_v

# %%
max_min_diff(flight['ARR_DELAY'])
# Out:
# 1245.0

# %%
# 사용자 함수를 agg에서 사용할 경우, 문자열이 아닌 함수자체를 전달
flight['ARR_DELAY'].agg(['max', 'min', max_min_diff])
# Out:
# max             1185.0
# min              -60.0
# max_min_diff    1245.0
# Name: ARR_DELAY, dtype: float64

# %%
flight[['ARR_DELAY','DEP_DELAY']].agg(['max', 'min', max_min_diff])
# Out:
#               ARR_DELAY  DEP_DELAY
# max              1185.0     1194.0
# min               -60.0      -24.0
# max_min_diff     1245.0     1218.0

# %%
# IQR값을 계산하는 사용자 정의 집계함수를 만들어서
# ['ARR_DELAY','DEP_DELAY'] 컬럼의 IQR값 조회
# IQR : Inter Quantile Range의 약자 -> 3사분위수 - 1사분위수 = 1~2분위수의 범위
def iqr(x : pd.Series):
    q3 = x.quantile(0.75)
    q1 = x.quantile(0.25)
    return q3 - q1

# %%
flight[['ARR_DELAY','DEP_DELAY']].agg([iqr])
# Out:
#      ARR_DELAY  DEP_DELAY
# iqr       21.0       14.0

# %% [markdown]
# # TODO

# %%
# 1. data/diamonds.csv 를 읽어 DataFrame 생성
dia_df = pd.read_csv(r'./data/diamonds.csv')

# %%
# 2. 1에서 생성한 DataFrame의 정보 조회
#     - 배열의 shape조회
dia_df.shape
# Out:
# (53940, 10)

# %%
#     - DataFrame에 대한 정보조회
dia_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
#     - 상위 5개 행 조회
dia_df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#     - 하위 5개 행 조회
dia_df.tail()
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64

# %%
#     - 결측치 확인
dia_df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
# 3. carat, price, depth의 합계, 평균, 최대, 최소 조회
dia_df[['carat', 'price', 'depth']].agg(['sum', 'mean', 'max', 'min']).head()
# Out:
#             carat         price         depth
# sum   43040.87000  2.121352e+08  3.330763e+06
# mean      0.79794  3.932800e+03  6.174940e+01
# max       5.01000  1.882300e+04  7.900000e+01
# min       0.20000  3.260000e+02  4.300000e+01

# %%
# 4. price는 최대, 최소, color는 고유값의 개수를 조회
d_param = {
    'price' : ['max', 'min'],
    'color' : 'nunique'
}
dia_df.agg(d_param)
# Out:
#            price  color
# max      18823.0    NaN
# min        326.0    NaN
# nunique      NaN    7.0

# %%
# 5. cut의 고유값별 개수를 조회
dia_df['cut'].value_counts().to_frame()
# Out:
#            count
# cut
# Ideal      21551
# Premium    13791
# Very Good  12082
# Good        4906
# Fair        1610

# %%
# 6. cut별 가격 평균 조회
dia_df.groupby('cut')['price'].mean().to_frame()
# Out:
#                  price
# cut
# Fair       4358.757764
# Good       3928.864452
# Ideal      3457.541970
# Premium    4584.257704
# Very Good  3981.759891

# %%
# 7. cut별 가격 평균중 4000이상만 조회
dia_df.groupby('cut')['price'].mean().to_frame().query('price >= 4000')
# Out:
#                price
# cut
# Fair     4358.757764
# Premium  4584.257704

# %%
# 7. cut별 가격 평균중 4000이상만 조회
dia_df.groupby('cut')['price'].agg(['mean']).query('mean >= 4000')
# Out:
#                 mean
# cut
# Fair     4358.757764
# Premium  4584.257704

# %%
# 8. clarity별 carat 평균과 표준편차 조회
dia_df.groupby('clarity')['carat'].agg(['mean', 'std'])
# Out:
#              mean       std
# clarity
# I1       1.283846  0.632436
# IF       0.505123  0.313433
# SI1      0.850482  0.449652
# SI2      1.077648  0.516653
# VS1      0.727158  0.423529
# VS2      0.763935  0.446292
# VVS1     0.503321  0.299557
# VVS2     0.596202  0.359697

# %%
# 9. cut과 color 별로 가격은 평균을 carat은 최대값을 조회 
d_param = {
    'price':'mean',
    'carat':'max'
}
dia_df.groupby(['cut', 'color'])[['price', 'carat']].agg(d_param)
# Out:
#                        price  carat
# cut       color
# Fair      D      4291.061350   3.40
#           E      3682.312500   2.04
#           F      3827.003205   2.58
#           G      4239.254777   2.60
#           H      5135.683168   4.13
#           I      4685.445714   3.02
#           J      4975.655462   5.01
# Good      D      3405.382175   2.04
#           E      3423.644159   3.00
#           F      3495.750275   2.67
#           G      4123.482204   2.80
#           H      4276.254986   3.01
#           I      5078.532567   3.01
#           J      4574.172638   3.00
# Ideal     D      2629.094566   2.75
#           E      2597.550090   2.28
#           F      3374.939362   2.45
#           G      3720.706388   2.54
#           H      3889.334831   3.50
#           I      4451.970377   3.22
#           J      4918.186384   3.01
# Premium   D      3631.292576   2.57
#           E      3538.914420   3.05
#           F      4324.890176   3.01
# ...

# %%
# 10. 9번 문제의 결과에서 가격의 평균이 5000이상이고 carat의 최대값이 3이상인 결과만 조회
d_param = {
    'price':'mean',
    'carat':'max'
}
q_param = 'price >= 5000 and carat >= 3'
dia_df.groupby(['cut', 'color'])[['price', 'carat']].agg(d_param).query(q_param)
# Out:
#                        price  carat
# cut       color
# Fair      H      5135.683168   4.13
# Good      I      5078.532567   3.01
# Premium   H      5216.706780   3.24
#           I      5946.180672   4.01
#           J      6294.591584   4.01
# Very Good I      5255.879568   4.00
