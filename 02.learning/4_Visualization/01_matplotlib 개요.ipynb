# %% [markdown]
# # 데이터 시각화의 개념 및 필요성
#
# ## 데이터 시각화
# - 데이터의 분석 결과를 쉽게 이해하고 판단할 수 있도록 데이터를 시각적으로 표현하여 전달하기 위한 과정을 말한다.
#
# ## 필요성
# - 많은 양의 데이터를 한눈에 파악할 수 있다. 시각적 요소를 활용해 데이터를 요약한다.
# - 데이터 분석에 대한 전문적 지식이 없더라도 누구나 해당 데이터를 인지하고 활용할 수있게한다.
#     - 사람이 감각기관을 통해 획득하는 정보의 80%는 시각에 의한 것이다.
#     - 시각적인 입력은 다른 어떤 방법보다 빠르고 쉽게 사람이 이해할 수 있다.
#     - 시각화 형태, 요소, 위치, 색등을 기반으로 패턴이나 다양한 인사이트(의미있는 정보)를 도출 및 표현할 수 있다.
# - 단순한 데이터 요약, 통계분석 결과보다 정확한 데이터 분석결과를 도출할 수있다.
#     - 데이터의 패턴이나 추세, 데이터간 비교등 표(Table)로 쉽게 인식 할 수 없는 것들을 시각적으로 쉽게 확인할 수 있다.
#
# # 대표적 파이썬 시각화 라이브러리
# - matplotlib
# - seaborn
# - pandas
# - plotly
# - folium

# %% [markdown]
# #  Matplotlib
# - 데이터의 시각화를 위한 파이썬 패키지
# - 2차원 그래프를 위한 패키지이나 확장 API들을 이용해 3D 그래프등 다양한 형식의 시각화를 지원
# - 파이썬 기반의 다른 시각화 패키지의 기본이 된다.
#     - Seaborn, Pandas 등이 Matplotlib를 기반으로 사용한다.
# - https://matplotlib.org

# %% [markdown]
# ## 장점
# - 동작하는 OS를 가리지 않는다.
# - MATLAB과 유사한 사용자 인터페이스를 가진다.
# - 그래프에 대한 상세한 설정을 할 수 있다.
# - 다양한 출력 형식으로 저장할 수 있다.

# %% [markdown]
# ## matplotlib 그래프 구성요소
# ![image.png](attachment:image.png)

# %% [markdown]
# - **figure**
#     - 전체 그래프가 위치할 기본 틀
#     - 하나의 figure에 여러개의 그래프를 그릴 수 있다.
#     - https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.figure.html
# - **axes(subplot)**
#     - figure내에 한개의 그래프를 그리기 위한 공간
#         - figure에 한개 이상의 axes(subplot)로 구성해서 각 axes에 그래프를 그린다.
#     - https://matplotlib.org/stable/api/axes_api.html
# - **axis**
#     - 축 (x축, y축)은 값들을 위치시키는 선을 말한다.
#     - axis label (x, y) : 축의 레이블(설명)
# - **ticks** : 축의 값을 알려주는 눈금
#     - Major tick
#     - Minor tick
# - **title** : 플롯 제목
# - **legend (범례)**
#     - 하나의 axes내에 여러 그래프를 그린 경우 그것에 대한 설명

# %%
# %matplotlib inline
# %matplotlib qt

# matplotlib: 파이썬에서 데이터를 차트나 플롯(Plot)으로 시각화하는 패키지
# pyplot: matplotlib의 서브 패키지로서, 간단한 plot을 그릴 때 사용
import matplotlib.pyplot as plt
import numpy as np

# 한개의 figure에 여러개의 subplot 그리기
fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
# 첫번쩨 subplot -> 1행 2열의 첫번째
axes1 = fig.add_subplot(1,2,1)
# 두번째 subplot -> 1행 2열의 두번째
axes2 = fig.add_subplot(1,2,2)

# plot 그리기 -> 선그래프
# plot(x축 데이터, y축 데이터, 선스타일, label='라벨')
axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
# scatter 그리기 -> 산점도
# scatter(x축 데이터, y축 데이터, 마커모양, 마커색, label='라벨')
axes2.scatter(np.random.randint(100, size=50),
              np.random.randint(100, 200, size=50),
              color='r',
              label='scatter1')
axes2.scatter(np.random.randint(25, 75, size=50),
              np.random.randint(125, 175, size=50),
              color='b',
              label='scatter2')

# figure의 title 설정
# size: 폰트크기, color: 글자색
# 글자색은 영문 RGB(HEX)코드로 설정 또는 색상이름으로 설정 가능
fig.suptitle('Example of Plot', size=25, color='blue') 
# 각 plot의 title 설정
axes1.set_title("PLOT 1", size=20, color='#ffbbbb')
axes2.set_title("Plot 2", size=20, color='#bbffbb')

# 각 subplot의 tick(x축, y축)의 label 설정
axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

# 각 subplot의 legend 설정 (legend: 범례)
axes1.legend()
axes2.legend()
# subplot의 grid 설정 (grid: 격자)
axes1.grid(True)
# figure 출력
plt.show()
# # 주피터 노트북의 경우 코드의 마지막에 ;를 붙이면 출력됨
# ;

# %%
# %matplotlib inline
# pyqt5를 이용하여 figure를 새창으로 출력
# %matplotlib qt

# matplotlib: 파이썬에서 데이터를 차트나 플롯(Plot)으로 시각화하는 패키지
# pyplot: matplotlib의 서브 패키지로서, 간단한 plot을 그릴 때 사용
import matplotlib.pyplot as plt
import numpy as np

# 한개의 figure에 여러개의 plot을 그리기
fig = plt.figure(figsize=(15,7), facecolor='gray') #facecolor: figure의 배경색
# 첫번쩨 plot -> 1행 2열의 첫번째
axes1 = fig.add_subplot(1,2,1)
# 두번째 plot -> 1행 2열의 두번째
axes2 = fig.add_subplot(1,2,2)

# plot 그리기 -> 선그래프
# plot(x축 데이터, y축 데이터, 선스타일, label='라벨')
axes1.plot([1,2,3,4,5], [10,20,30,40,50], label='line1')
axes1.plot([1,2,3,4,5], [50,40,30,20,10], label='line2')
# scatter 그리기 -> 산점도
# scatter(x축 데이터, y축 데이터, 마커모양, 마커색, label='라벨')
axes2.scatter(np.random.randint(100, size=50),
              np.random.randint(100, 200, size=50),
              color='r',
              label='scatter1')
axes2.scatter(np.random.randint(25, 75, size=50),
              np.random.randint(125, 175, size=50),
              color='b',
              label='scatter2')

# figure의 title 설정
# size: 폰트크기, color: 글자색
# 글자색은 영문 RGB(HEX)코드로 설정 또는 색상이름으로 설정 가능
fig.suptitle('Example of Plot', size=25, color='blue') 
# 각 plot의 title 설정
axes1.set_title("PLOT 1", size=20, color='#ffbbbb')
axes2.set_title("Plot 2", size=20, color='#bbffbb')

# 각 subplot의 tick(x축, y축)의 label 설정
axes1.set_xlabel("X축", size=15)
axes1.set_ylabel("Y축", size=15)
axes2.set_xlabel("가격1", size=15)
axes2.set_ylabel('가격2', size=15)

# 각 subplot의 legend 설정 (legend: 범례)
axes1.legend()
axes2.legend()
# subplot의 grid 설정 (grid: 격자)
axes1.grid(True)
# figure 출력
plt.show()
# # 주피터 노트북의 경우 코드의 마지막에 ;를 붙이면 출력됨
# ;

# %% [markdown]
# # 그래프 그리기
# 1. matplotlib.pyplot 모듈을 import
#     - 2차원 그래프(axis가 두개인 그래프)를 그리기위한 함수를 제공하는 모듈
#     - 별칭(alias) 로 plt를 관례적으로 사용한다.
#     - `import matplotlib.pyplot as plt`
#
# 2. 그래프를 그린다.
#
# 3. 그래프에 필요한 설정을 한다.
#
# 4. 화면에 그린다.
#     - 지연 랜더링(Deferred rendering) 메카니즘
#     - 마지막에 `pyplot.show()` 호출 시 그래프를 그린다.
#         - ~~주피터 노트북 맨 마지막 코드에 `;`를 붙이는 것으로 대체할 수 있다.~~

# %% [markdown]
# # 그래프를 그리는 두가지 방식
# - pyplot 모듈의 함수들을 사용한다.
# - Figure와 Axes 객체의 메소드들을 사용한다.

# %% [markdown]
# ## pyplot 모듈을 이용해 그리기
# 1. pyplot 모듈이 그래프 그리는 함수와 Axes(Subplot) 설정 관련 함수를 제공

# %%
# 그래프를 그릴때 사용할 데이터셋
x = [1,2,3,4,5]         # x축 데이터
y = [10,20,30,40,50]    # y축 데이터

# %%
# %matplotlib inline
# 1. import
import matplotlib.pyplot as plt
# figure의 크기 설정
# figsize=(가로크기, 세로크기) -> 단위: inch
plt.figure(figsize=(8,6))

# 2. plot 그리기
plt.plot(x, y)

# 3. 그래프에 대한 추가적인 설정
plt.title('예제')   # 그래프 제목
plt.xlabel('x축')   # x축 이름
plt.ylabel('y축')
plt.grid(True)      # 그래프에 grid(격자) 표시
plt.xticks(x)       # x축 눈금 라벨 설정 -> x축 데이터와 같게 설정
plt.yticks(y, labels=['가','나','다','라','마']) # y축 눈금 라벨 설정 -> 라벨을 직접 설정

# 4. 그래프 출력
plt.show()

# %% [markdown]
# 2. 하나의 figure에 여러 그래프 그리기
#     - plt.subplot(row,columns,num)

# %%
import matplotlib.pyplot as plt
# 하나의 axes(subplot)에 여러개의 그래프를 그리기
plt.bar(y+x,y+x, label='bar')
plt.plot(x+y,x+y, color='r', label='line')
plt.scatter(y+x,x+y, color='#22DD00', label='scatter', marker='x')
plt.legend()
plt.show()

# %%
# 1. import
import matplotlib.pyplot as plt
# figure의 크기 설정
plt.figure(figsize=(7,7))
# 각 그래프를 설정
# 위치 지정후, 그래프 그리기
plt.subplot(2,2,1)
plt.title('1번 그래프')
plt.xlabel('x축')
plt.ylabel('y축')
plt.plot(x, y)

plt.subplot(2,2,2)
plt.title('2번 그래프')
plt.xlabel('x축')
plt.ylabel('y축')
# scatter 그래프 그리기 -> scatter: 산점도를 그릴 때 사용
plt.scatter(x, y, marker='x')

plt.subplot(2,2,3)
plt.title('3번 그래프')
# bar 그래프 그리기 -> bar: 양적인 비교를 할 때 사용
plt.bar(x, y)

plt.subplot(2,2,4)
plt.title('3번 그래프')
# pie 그래프 그리기 -> pie: 비율을 나타낼 때 사용
plt.pie(x, autopct='%.2f') 

plt.tight_layout() # 그래프간의 간격을 자동으로 맞춤
plt.show()

# %% [markdown]
# ## Figure 와 Axes 객체를 이용해 그리기
#
# - AxesSubplot 객체(Axes를 표현하는 객체)의 메소드들을 이용해 그래프를 그린다.
# - axes 생성 방법
#     - plt.gca(): AxesSubplot
#         - 하나의 figure에 하나의 Axes 만 사용할 경우 사용.
#     - 하나의 figure에 여러개의 Axes들을 사용할 경우
#         - figure.add_subplot() 메소드 이용
#             - figure를 먼저 생성후 axes 들을 추가
#         - pyplot.subplots() 함수를 이용
#             - figure와 axes배열을 동시에 생성

# %% [markdown]
# ### Figure에 하나의 axes 그리기
# - plt.gca() 사용

# %%
# 1. import
import matplotlib.pyplot as plt
# figure의 크기 설정
plt.figure(figsize=(3,3))

ax = plt.gca() # 현재 axes를 얻어옴
ax.plot(x, y, label='line1')
ax.plot(x, y[::-1], label='line2')
ax.set_title('1번')
ax.grid(True, linestyle='--', linewidth=1, alpha=0.5, color='#ff0084') # grid 설정
plt.show()

# %% [markdown]
# ### 하나의 Figure에 여러개의 axes 그리기
# 1. <b style='font-size:1.3em'>figure.add_subplot() 메소드 이용</b>
#     - figure객체에 axes를 추가하는 형태
#     - nrows(총행수), ncols(총열수), index(axes위치) 지정

# %%
# 1. import
import matplotlib.pyplot as plt
# figure의 크기 설정
fig = plt.figure(figsize=(5,5))

# 2. subplot들의 위치를 설정
# 전체 figure의 행, 열갯수와 몇번째 subplot인지를 설정
ax1 = fig.add_subplot(2,2,1) # 2행 2열의 첫번째 subplot
ax2 = fig.add_subplot(1,2,2) # 1행 2열의 두번째 subplot
ax3 = fig.add_subplot(223) # 2행 2열의 세번째 subplot

ax1.set_title('1번')
ax1.plot(x, y)
ax2.set_title('2번')
ax2.scatter(x, y)
ax3.set_title('3번')
ax3.bar(x, y)

plt.tight_layout()
plt.show()

# %% [markdown]
# 2. <b style='font-size:1.3em'>pyplot.subplots()</b>
#     - nrows, ncols 로 axes개수와 위치 지정
#     - 반환: figure와 axes(subplot)들을 담은 **ndarray**

# %%
# plt.subplots() 함수를 사용하여 여러개의 subplot을 그리기
# fig객체와 axes 다차원 배열을 반환
fig, axes = plt.subplots(2,2, figsize=(5,5))

axes = axes.flatten() # 2차원 배열을 1차원 배열로 변환
for i, ax in enumerate(axes):
    ax.set_title(f'{i+1}번')
    # 각 subplot에 그래프를 그림
    # .text() 함수를 사용하여 각 subplot의 위치에 subplot의 title을 출력
    ax.text(0.5, 0.5,       # text를 출력할 위치 (x, y)
            f'ax{i+1}',     # 출력할 text
            fontsize=20)    # text의 크기
            # ha='center'     # horizontal alignment: 수평정렬 (left, center, right)
            # va='center'     # vertical alignment: 수직정렬 (top, center, bottom)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 색상과 스타일
#
# ## 색 지정
# - color 또는 c 매개변수를  이용해 지정
# - **색상이름으로 지정.**
#     - 색이름 또는 약자로 지정 가능
#     - 'red', 'r'
#
# | 문자열 | 약자 |
# |-|-|
# | `blue` | `b` |
# | `green` | `g` |
# | `red` | `r` |
# | `cyan` | `c` |
# | `magenta` | `m` |
# | `yellow` | `y` |
# | `black` | `k` |
# | `white` | `w` |
#
#
# - **HTML Color Hex code**
#     - #으로 시작하며 RGB의 성분을 16진수로 표현
#     - #RRGGBB 또는 #RRGGBBAA
#     - #FF0000, #00FF00FA
# - **0 ~ 1 사이 실수로 흰식과 검정색 사이의 회색조를 표시**
#     - 0: 검정, 1: 흰색
# - **color 값 검색**
#     - https://matplotlib.org/examples/color/named_colors.html
#     - https://htmlcolorcodes.com/
#         - picker, chart(코드), name(색이름) 제공사이트
#     - google 에서 `color picker`로 검색

# %%
fig, axs = plt.subplots(2,2, figsize=(3,3))
axs[0,0].plot(x, y, c='green')          # c: color
axs[0,1].plot(x, y, c='r', alpha=0.5)   # alpha: 투명도
axs[1,0].plot(x, y, c='0.5')            # 0~1 사이의 실수로 흑백을 나타냄
axs[1,1].plot(x, y, c='#ff00ff88')      # #ff00ff88: #ff00ff + 88(투명도)

# %% [markdown]
# ## Style
# - Style: 그래프의 여러 시각효과들을 미리 설정해 놓은 것
# - matplotlib는 다양한 스타일들을 미리 정의해 놓고 있다.
#     - [스타일목록](https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html)
#     - `plt.style.use()` 함수 이용해 지정
#     - `plt.style.available`
#         - 사용할 수 있는 스타일 이름 조회

# %%
plt.style.available # 사용가능한 스타일 목록
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')                # 스타일 초기화
plt.style.use('seaborn-v0_8-pastel')    # 스타일 적용

# %%
plt.plot(x, y)
plt.show()

# %%
plt.plot(x, y)
plt.plot(x[::-1], y)
plt.show()

# %%
plt.pie(x+y) # autopct: pie 그래프에 비율 출력
plt.show()
