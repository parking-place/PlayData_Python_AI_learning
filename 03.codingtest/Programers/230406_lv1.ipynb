# %% [markdown]
# ![image.png](attachment:image.png)
# [Docs](https://docs.google.com/spreadsheets/d/19C7mMfD_XhmKW7TTXNR5XwVw8ycyaO_L1OCWF0CoqD4/edit#gid=546184874)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(a, b):
    answer = 0
    
    # a와 b의 크기를 비교하여 작은 수부터 큰 수까지의 합을 구한다.
    answer = sum(list(range(min(a,b), max(a,b)+1)))
    
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = ''
    watermelon = '수박'
    
    for i in range(n):
        answer += watermelon[i%2]
    
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(seoul):
    answer = ''
    answer = '김서방은 {}에 있다'.format(seoul.index('Kim'))
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = 0
    for i in range(1, n+1) :
        if n % i == 0 :
            answer += i
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(s):
    answer = 0
    for i in range(len(s)) :
        if s[i] == 'p' or s[i] == 'P' :
            answer += 1
        elif s[i] == 'y' or s[i] == 'Y' :
            answer -= 1
    return not answer
    
    # [실행] 버튼을 누르면 출력 값을 볼 수 있습니다.
    print('Hello Python')

    return answer

# %% [markdown]
# # 성공
# 0 == False, 그외엔 True인 것을 이용

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr):
    answer = []
    
    for i in range(len(arr)) :
        if i == 0 :
            answer.append(arr[i])
        elif arr[i] != arr[i-1] :
            answer.append(arr[i])
            
    return answer

# %% [markdown]
# # 성공
# i = 0일 경우에만 예외처리 필요

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(x, n):
    answer = []
    
    for i in range(1, n+1) :
        answer.append(x*i)
    
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
n, m = map(int, input().strip().split(' '))

for i in range(m) :
    for j in range(n) :
        print('*', end='')
    print()
# Out:
# *
# *

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr):
    answer = sum(arr) / len(arr)
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(arr1, arr2):
    answer = [[]]
    
    # answer을 컴프리헨션으로 초기화
    # [ [0 for j in range(안쪽 리스트 길이))] for i in range(바깥쪽 리스트 길이)]
    answer = [[0 for j in range(len(arr1[0]))] for i in range(len(arr1))]
    
    # answer에 arr1과 arr2의 값을 더해준다.
    for i in range(len(arr1)) :
        for j in range(len(arr1[0])) :
            answer[i][j] = arr1[i][j] + arr2[i][j]
    return answer

# %%
arr1 = [[1,2],[2,3]]
arr2 = [[3,4],[5,6]]
solution(arr1, arr2)
# Out:
# [[4, 6], [7, 9]]

# %%
arr1 = [[1],[2]]
arr2 = [[3],[4]]
solution(arr1, arr2)
# Out:
# [[4], [6]]

# %% [markdown]
# # 성공
# 다차원 배열의 컴프리헨션 초기화 -> 가독성이 좋지않고 복잡해짐. # 주석 필수
# 다차원 배열의 덧셈은 행과 열이 같음

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(num):
    answer = ''
    if num%2 == 0 :
        answer = 'Even'
    else :
        answer = 'Odd'
    return answer

# %% [markdown]
# # 성공

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = 0
    l = [int(v) for v in str(n)]
    answer = sum(l)
    return answer

# %% [markdown]
# # 성공
# - num % 10 ** i 가 아닌 문자열을 통한 자릿수 나눔

# %% [markdown]
# ![image.png](attachment:image-2.png)

# %%
def solution(n, m):
    answer = []
    
    # 최대 공약수를 구해 answer에 추가
    # 거꾸로 돌면서 나누어 떨어지는 수를 찾아야
    # 최댓값만 찾을 수 있다.
    for i in range(min(n,m), 0, -1) :
        if n%i == 0 and m%i == 0 :
            answer.append(i)
            break
     
    # 최소 공배수를 구해 answer에 추가
    for i in range(max(n,m), n*m+1) :
        if i%n == 0 and i%m == 0 :
            answer.append(i)
            break
    
    return answer

# %% [markdown]
# # 성공
# - 공약수는 반대방향으로 최댓값을 찾아야함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def solution(n):
    answer = 0
    
    if n**0.5 == int(n**0.5) :
        answer = (n**0.5 + 1)**2
    else :
        answer = -1
    
    return answer

# %%
print(1.6, int(1.6))
# Out:
# 1.6 1

# %%
# 더 줄일 수 있음
def solution(n):
    return int((n**0.5 + 1)**2) if n**0.5 == int(n**0.5) else -1

# %% [markdown]
# # 성공
# - int(n**0.5)의 try except을 이용해 보려 하였으나 생각해보니 오류나지 않고 int로 반환함
# - int형으로 값이 변경되기 떄문에 비교를 통해 확인함.
